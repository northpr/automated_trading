# %%
import pandas as pd

# %%
pd.read_excel("data/SP500.xls").info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12107 entries, 0 to 12106
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       12107 non-null  datetime64[ns]
#  1   Open       12107 non-null  float64
#  2   High       12107 non-null  float64
#  3   Low        12107 non-null  float64
#  4   Close      12107 non-null  float64
#  5   Adj Close  12107 non-null  float64
#  6   Volume     12107 non-null  int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 662.2 KB

# %%
pd.read_excel("data/SP500.xls", parse_dates=["Date"], index_col="Date")
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 1970-12-31    92.269997    92.790001    91.360001    92.150002    92.150002
# 1971-01-04    92.150002    92.190002    90.639999    91.150002    91.150002
# 1971-01-05    91.150002    92.279999    90.690002    91.800003    91.800003
# 1971-01-06    91.800003    93.000000    91.500000    92.349998    92.349998
# 1971-01-07    92.349998    93.260002    91.750000    92.379997    92.379997
# ...                 ...          ...          ...          ...          ...
# 2018-12-21  2465.379883  2504.409912  2408.550049  2416.620117  2416.620117
# 2018-12-24  2400.560059  2410.340088  2351.100098  2351.100098  2351.100098
# 2018-12-26  2363.120117  2467.760010  2346.580078  2467.699951  2467.699951
# 2018-12-27  2442.500000  2489.100098  2397.939941  2488.830078  2488.830078
# 2018-12-28  2498.770020  2520.270020  2472.889893  2485.739990  2485.739990
#
#                 Volume
# Date
# ...

# %%
pd.read_excel("data/SP500.xls", parse_dates=["Date"], index_col="Date", usecols="A:G")
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 1970-12-31    92.269997    92.790001    91.360001    92.150002    92.150002
# 1971-01-04    92.150002    92.190002    90.639999    91.150002    91.150002
# 1971-01-05    91.150002    92.279999    90.690002    91.800003    91.800003
# 1971-01-06    91.800003    93.000000    91.500000    92.349998    92.349998
# 1971-01-07    92.349998    93.260002    91.750000    92.379997    92.379997
# ...                 ...          ...          ...          ...          ...
# 2018-12-21  2465.379883  2504.409912  2408.550049  2416.620117  2416.620117
# 2018-12-24  2400.560059  2410.340088  2351.100098  2351.100098  2351.100098
# 2018-12-26  2363.120117  2467.760010  2346.580078  2467.699951  2467.699951
# 2018-12-27  2442.500000  2489.100098  2397.939941  2488.830078  2488.830078
# 2018-12-28  2498.770020  2520.270020  2472.889893  2485.739990  2485.739990
#
#                 Volume
# Date
# ...

# %%
sp500 = pd.read_excel("data/SP500.xls", parse_dates=["Date"], index_col = "Date", usecols="A:E")

# %%
sp500.head()
# Out:
#                  Open       High        Low      Close
# Date
# 1970-12-31  92.269997  92.790001  91.360001  92.150002
# 1971-01-04  92.150002  92.190002  90.639999  91.150002
# 1971-01-05  91.150002  92.279999  90.690002  91.800003
# 1971-01-06  91.800003  93.000000  91.500000  92.349998
# 1971-01-07  92.349998  93.260002  91.750000  92.379997

# %%
df = pd.read_csv("data/sp500.csv", parse_dates=["Date"], index_col="Date")

# %%
close = df["Close"].to_frame()

# %%
import matplotlib.pyplot as plt

close.plot(figsize=(10,7))
plt.legend()
plt.show()

# %%
close = close.loc["2008-12-31":"2018-12-31"].copy()

# %%
close.head(15)
# Out:
#                  Close
# Date
# 2008-12-31  903.250000
# 2009-01-02  931.799988
# 2009-01-05  927.450012
# 2009-01-06  934.700012
# 2009-01-07  906.650024
# 2009-01-08  909.729980
# 2009-01-09  890.349976
# 2009-01-12  870.260010
# 2009-01-13  871.789978
# 2009-01-14  842.619995
# 2009-01-15  843.739990
# 2009-01-16  850.119995
# 2009-01-20  805.219971
# 2009-01-21  840.239990
# 2009-01-22  827.500000

# %%
close.rolling(window=10)
# Out:
# Rolling [window=10,center=False,axis=0,method=single]

# %%
close.rolling(window=10).mean()
# Out:
#                   Close
# Date
# 2008-12-31          NaN
# 2009-01-02          NaN
# 2009-01-05          NaN
# 2009-01-06          NaN
# 2009-01-07          NaN
# ...                 ...
# 2018-12-21  2565.915991
# 2018-12-24  2537.254004
# 2018-12-26  2520.345996
# 2018-12-27  2504.121997
# 2018-12-28  2487.641992
#
# [2516 rows x 1 columns]

# %%
close.rolling(window=10, min_periods=10).mean()
# Out:
#                   Close
# Date
# 2008-12-31          NaN
# 2009-01-02          NaN
# 2009-01-05          NaN
# 2009-01-06          NaN
# 2009-01-07          NaN
# ...                 ...
# 2018-12-21  2565.915991
# 2018-12-24  2537.254004
# 2018-12-26  2520.345996
# 2018-12-27  2504.121997
# 2018-12-28  2487.641992
#
# [2516 rows x 1 columns]

# %% [markdown]
# # Momentum trading strategies with SMAs (Simple Moving Average)

# %%
## Momentum trading strategies with SMAs
df.head()
# Out:
#                  Open       High        Low      Close
# Date
# 1970-12-31  92.269997  92.790001  91.360001  92.150002
# 1971-01-04  92.150002  92.190002  90.639999  91.150002
# 1971-01-05  91.150002  92.279999  90.690002  91.800003
# 1971-01-06  91.800003  93.000000  91.500000  92.349998
# 1971-01-07  92.349998  93.260002  91.750000  92.379997

# %%
sp500 = df["Close"].to_frame()

# %%
sp500.tail()
# Out:
#                   Close
# Date
# 2018-12-21  2416.620117
# 2018-12-24  2351.100098
# 2018-12-26  2467.699951
# 2018-12-27  2488.830078
# 2018-12-28  2485.739990

# %%
sp500["sma50"] = sp500.rolling(window=50,min_periods=50).mean()

# %%
sp500
# Out:
#                   Close        sma50
# Date
# 1970-12-31    92.150002          NaN
# 1971-01-04    91.150002          NaN
# 1971-01-05    91.800003          NaN
# 1971-01-06    92.349998          NaN
# 1971-01-07    92.379997          NaN
# ...                 ...          ...
# 2018-12-21  2416.620117  2692.420195
# 2018-12-24  2351.100098  2684.874795
# 2018-12-26  2467.699951  2678.886196
# 2018-12-27  2488.830078  2673.646997
# 2018-12-28  2485.739990  2667.163398
#
# [12107 rows x 2 columns]

# %%
sp500.plot(figsize=(12,8), fontsize=15)
plt.legend(loc="upper left", fontsize=15)

# %%
sp500["sma200"] = sp500["Close"].rolling(window=200).mean()

# %%
sp500 = sp500.loc["2008-12-31":"2018-12-31"].copy()

# %%
sp500.head()
# Out:
#                  Close       sma50     sma200
# Date
# 2008-12-31  903.250000  887.264001  1184.5795
# 2009-01-02  931.799988  886.799001  1182.7464
# 2009-01-05  927.450012  887.412401  1180.7361
# 2009-01-06  934.700012  887.944202  1178.6602
# 2009-01-07  906.650024  888.541802  1176.4285

# %%
sp500.plot(figsize=(10,7))
plt.legend()
plt.grid()

# %%
sp500.iloc[:,1:].plot(figsize=(10,7))
plt.grid()
plt.show()

# %% [markdown]
# ### Conslusion - Simple Moving Average
# We should invest when SMA50 is above SMA200. For example
# - 2010 -> 2011, 2012 -> 2016

# %% [markdown]
# ## EWMA

# %%
sp500 = sp500["Close"].loc["2008-12-31":"2018-12-31"].copy()

# %%
sp500 = sp500.to_frame()

# %%
sp500.head()
# Out:
#                  Close
# Date
# 2008-12-31  903.250000
# 2009-01-02  931.799988
# 2009-01-05  927.450012
# 2009-01-06  934.700012
# 2009-01-07  906.650024

# %%
sp500["Close"].rolling(window=10).mean()
# Out:
# Date
# 2008-12-31            NaN
# 2009-01-02            NaN
# 2009-01-05            NaN
# 2009-01-06            NaN
# 2009-01-07            NaN
#                  ...
# 2018-12-21    2565.915991
# 2018-12-24    2537.254004
# 2018-12-26    2520.345996
# 2018-12-27    2504.121997
# 2018-12-28    2487.641992
# Name: Close, Length: 2516, dtype: float64

# %%
sp500["Close"].ewm(span=10, min_periods=10).mean()
# Out:
# Date
# 2008-12-31            NaN
# 2009-01-02            NaN
# 2009-01-05            NaN
# 2009-01-06            NaN
# 2009-01-07            NaN
#                  ...
# 2018-12-21    2547.124619
# 2018-12-24    2511.483797
# 2018-12-26    2503.523098
# 2018-12-27    2500.851640
# 2018-12-28    2498.104067
# Name: Close, Length: 2516, dtype: float64

# %%
sp500["sma"] = sp500["Close"].rolling(window=100).mean()
sp500["ema"] = sp500["Close"].ewm(span=100).mean()

# %%
sp500.tail(100)
# Out:
#                   Close          sma          ema
# Date
# 2018-08-07  2858.449951  2724.994802  2746.932312
# 2018-08-08  2857.699951  2726.051702  2749.125731
# 2018-08-09  2853.580078  2727.458303  2751.194134
# 2018-08-10  2833.280029  2728.621704  2752.819597
# 2018-08-13  2821.929932  2729.721704  2754.188118
# ...                 ...          ...          ...
# 2018-12-21  2416.620117  2785.905496  2732.088580
# 2018-12-24  2351.100098  2781.282896  2724.544253
# 2018-12-26  2467.699951  2777.687695  2719.458228
# 2018-12-27  2488.830078  2774.172495  2714.891334
# 2018-12-28  2485.739990  2770.525896  2710.353683
#
# [100 rows x 3 columns]

# %%
sp500.iloc[500:,1:].plot(figsize=(10,7),fontsize=10)
plt.legend()

# %% [markdown]
# ## Merging

# %%
df.head()
# Out:
#                  Open       High        Low      Close
# Date
# 1970-12-31  92.269997  92.790001  91.360001  92.150002
# 1971-01-04  92.150002  92.190002  90.639999  91.150002
# 1971-01-05  91.150002  92.279999  90.690002  91.800003
# 1971-01-06  91.800003  93.000000  91.500000  92.349998
# 1971-01-07  92.349998  93.260002  91.750000  92.379997

# %%
df = pd.read_csv("data/stocks.csv", header=[0,1], index_col=[0], parse_dates=[0])
df.head()
# Out:
#            Adj Close                                                         \
#                 AAPL         BA        DIS        IBM         KO       MSFT
# Date
# 2009-12-31  6.415359  42.180111  28.090704  80.363129  19.203474  23.323427
# 2010-01-04  6.515212  43.777550  27.933920  81.314713  19.216942  23.683073
# 2010-01-05  6.526477  45.211346  27.864237  80.332443  18.984484  23.690720
# 2010-01-06  6.422665  46.582802  27.716166  79.810631  18.977745  23.545340
# 2010-01-07  6.410792  48.468559  27.724874  79.534340  18.930574  23.300468
#
#                Close                                ...   Open              \
#                 AAPL         BA    DIS         IBM  ...    DIS         IBM
# Date                                                ...
# 2009-12-31  7.526071  54.130001  32.25  125.143402  ...  32.27  126.586998
# 2010-01-04  7.643214  56.180000  32.07  126.625237  ...  32.50  125.411087
# ...

# %%
df = df["Close"]

# %%
apple = df["AAPL"].loc["2010-01-01":"2014-12-31"].to_frame()
apple.head()
# Out:
#                 AAPL
# Date
# 2010-01-04  7.643214
# 2010-01-05  7.656429
# 2010-01-06  7.534643
# 2010-01-07  7.520714
# 2010-01-08  7.570714

# %%
ba = df["BA"].loc["2012-01-01":"2016-12-31"].to_frame()
ba.head()
# Out:
#                    BA
# Date
# 2012-01-03  74.220001
# 2012-01-04  74.330002
# 2012-01-05  73.529999
# 2012-01-06  73.980003
# 2012-01-09  74.529999

# %%
apple["BA"] = ba["BA"]

# %%
apple.head()
# Out:
#                 AAPL  BA
# Date
# 2010-01-04  7.643214 NaN
# 2010-01-05  7.656429 NaN
# 2010-01-06  7.534643 NaN
# 2010-01-07  7.520714 NaN
# 2010-01-08  7.570714 NaN

# %%
apple.tail()
# Out:
#                  AAPL          BA
# Date
# 2014-12-24  28.002501  131.240005
# 2014-12-26  28.497499  131.630005
# 2014-12-29  28.477501  132.289993
# 2014-12-30  28.129999  131.830002
# 2014-12-31  27.594999  129.979996

# %%
apple.dropna()
# Out:
#                  AAPL          BA
# Date
# 2012-01-03  14.686786   74.220001
# 2012-01-04  14.765714   74.330002
# 2012-01-05  14.929643   73.529999
# 2012-01-06  15.085714   73.980003
# 2012-01-09  15.061786   74.529999
# ...               ...         ...
# 2014-12-24  28.002501  131.240005
# 2014-12-26  28.497499  131.630005
# 2014-12-29  28.477501  132.289993
# 2014-12-30  28.129999  131.830002
# 2014-12-31  27.594999  129.979996
#
# [754 rows x 2 columns]

# %%
ba.reindex(apple.index).dropna()
# Out:
#                     BA
# Date
# 2012-01-03   74.220001
# 2012-01-04   74.330002
# 2012-01-05   73.529999
# 2012-01-06   73.980003
# 2012-01-09   74.529999
# ...                ...
# 2014-12-24  131.240005
# 2014-12-26  131.630005
# 2014-12-29  132.289993
# 2014-12-30  131.830002
# 2014-12-31  129.979996
#
# [754 rows x 1 columns]

# %%
df.loc["2010-01-01":"2016-12-31","DIS"].resample("W-Fri").last().to_frame()
# Out:
#                    DIS
# Date
# 2010-01-08   31.879999
# 2010-01-15   30.600000
# 2010-01-22   29.980000
# 2010-01-29   29.549999
# 2010-02-05   29.540001
# ...                ...
# 2016-12-02   98.500000
# 2016-12-09  104.860001
# 2016-12-16  103.910004
# 2016-12-23  105.150002
# 2016-12-30  104.220001
#
# [365 rows x 1 columns]
